# %% [markdown]
# ### Credit Card Churn
#
# Objective: Process and visualize data to predict churn. In this scenario, a bank manager noticed an increasing number of clients terminating their credit card services with the bank. The goal is to predict which customers will leave so that the bank can proactively offer more appealing services to the client, thereby convincing them to reconsider.
#
# Steps for the activity:
# 1. **Data Reading:** Using Pandas, read the database located in data/BankChunners. By the end of this step, the following questions can be answered:
#   * What are the input attributes of the dataset?
#   * What is the output attribute of the dataset?
#   * How many clients are there?
#   * Is there any correlation between the variables?
#
# 2. **Data Processing:** Check the status of the database, remove missing data, duplicates, and perform transformations on the attributes as necessary.
#
# 3. **Data Visualization:** Using Seaborn and Matplotlib for generate charts of the available data in various formats (e.g. barchart, pie chart, boxplot). Additionally, view data statistics.

# %% [markdown]
# ### Initiating the necessary imports for our evaluation

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 1. Reading and Processing the Database

# %%
df = pd.read_csv('data/BankChurners.csv')

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
df['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
# Seeking for Null Values
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
# Seeking for Duplicated Values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Step 2. Data Visualization and Descriptive Statistics

# %%
# Analysing the Age Values
df['Customer_Age'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Analysing the Gender Values
fig, ax1 = plt.subplots()
ax1.pie(df['Gender'].value_counts(), labels=df['Gender'].value_counts().index, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.tight_layout()

# %%
# Analysing the Dependent Values
plt.figure(figsize=(5,5))
sns.countplot(y = df['Dependent_count'])
plt.title('Dependent_count',color="blue")
plt.xlabel("Dependent_count")
plt.ylabel("Quantidade")
plt.show()

# %%
# Analysing the Education Values
plt.figure(figsize=(5,5))
sns.countplot(y = df['Education_Level'])
plt.title('Education_Level',color="blue")
plt.xlabel("Education_Level")
plt.ylabel("Quantidade")
plt.show()

# %%
# Analysing the Marital Values
bar_color = "#fcba03"

plt.figure(figsize=(5,5))
sns.countplot(y = df['Marital_Status'], color=bar_color)
plt.title('Marital_Status', color="black")
plt.xlabel('Marital_Status')
plt.ylabel("Quantidade")
plt.show()

# %%
# Analysing the Income Values
plt.figure(figsize=(5,5))
sns.countplot(y = df['Income_Category'])
plt.title('Income_Category',color="blue")
plt.xlabel('Income_Category')
plt.ylabel("Quantidade")
plt.show()

# %%
# Analysing the Card Values
plt.figure(figsize=(5,5))
sns.countplot(y = df['Card_Category'])
plt.title('Card_Category',color="blue")
plt.xlabel('Card_Category')
plt.ylabel("Quantidade")
plt.show()

# %%
# Summarizes statistical data of DataFrame.
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
# Displays boxplot for months of relationship
df['Months_on_book'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Displays boxplot for years relationship
df['Total_Relationship_Count'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Displays boxplot for months of inactive
df['Months_Inactive_12_mon'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Displays boxplot for numbers of contact
df['Contacts_Count_12_mon'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Plots histogram with age distribution
sns.histplot(df['Customer_Age'], kde=True)
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Count'>

# %%
# Plots histogram with month on book distribution
sns.histplot(df['Months_on_book'])
# Out:
# <Axes: xlabel='Months_on_book', ylabel='Count'>

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_filtered = df.drop(columns=['Attrition_Flag', 'Gender','Education_Level','Marital_Status','Income_Category','Card_Category','Months_on_book','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])
plt.figure(figsize=(20, 15))
sns.heatmap(df_filtered.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# #### Step 3 - Transforming Non-Numeric Data

# %%
df.drop(['Avg_Open_To_Buy', 'Total_Trans_Ct', 'CLIENTNUM', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],axis=1,inplace=True)
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Ct_Chng_Q4_Q1',
#        'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# #### One-hot encoding is a process that converts categorical data into a format that can be provided to machine learning algorithms to improve predictions. For each unique value in a column, a new column (or "dummy" column) is created, where the presence of the value is represented by a 1 or 0 (binary representation).

# %%
one_hot = pd.get_dummies(df[['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category']])
df = df.drop(['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'],axis = 1)
df = df.join(one_hot)
df
# Out:
#           Attrition_Flag  Customer_Age  Dependent_count  Months_on_book  \
# 0      Existing Customer            45                3              39
# 1      Existing Customer            49                5              44
# 2      Existing Customer            51                3              36
# 3      Existing Customer            40                4              34
# 4      Existing Customer            40                3              21
# ...                  ...           ...              ...             ...
# 10122  Existing Customer            50                2              40
# 10123  Attrited Customer            41                2              25
# 10124  Attrited Customer            44                1              36
# 10125  Attrited Customer            30                2              36
# 10126  Attrited Customer            43                2              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit_transform(df['Attrition_Flag'])
df['Attrition_Flag'] = le.fit_transform(df['Attrition_Flag'])

# %%
df
# Out:
#        Attrition_Flag  Customer_Age  Dependent_count  Months_on_book  \
# 0                   1            45                3              39
# 1                   1            49                5              44
# 2                   1            51                3              36
# 3                   1            40                4              34
# 4                   1            40                3              21
# ...               ...           ...              ...             ...
# 10122               1            50                2              40
# 10123               0            41                2              25
# 10124               0            44                1              36
# 10125               0            30                2              36
# 10126               0            43                2              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                             5                       1
# ...
